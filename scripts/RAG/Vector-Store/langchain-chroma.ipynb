# %%
# !pip install langchain chromadb openai tiktoken pypdf langchain_openai langchain-community langchain-chroma

# %%
from langchain_chroma import Chroma # type: ignore
from langchain.schema import Document
from langchain_huggingface import HuggingFaceEmbeddings

# %%
doc1 = Document(
    page_content="The movie 'The Shawshank Redemption' is a English film directed by Frank Darabont and written by Frank Darabont. It was released on 1994-09-23, with a streaming release on 1999-12-21. The film runs for 142.0 minutes and has a TMDB rating of 8.702 based on 24649.0 votes. It had a budget of 25000000.0 USD and grossed 28341469.0 USD in revenue. The movie falls under the genres: drama, crime. It was produced by Castle Rock Entertainment. The cast includes Tim Robbins, Morgan Freeman, Bob Gunton. The story: Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.",
    metadata={
       "title": "The Shawshank Redemption",
        "release_date": "1994-09-23",
        "release_date_streaming": "1999-12-21",
        "original_language": "English",
    }
)

doc2 = Document(
    page_content="The movie 'The Shape of Water' is a English film directed by Guillermo del Toro and written by Guillermo del Toro,Vanessa Taylor. It was released on 2017-12-01, with a streaming release on 2018-03-13. The film runs for 123.0 minutes and has a TMDB rating of 7.247 based on 11490.0 votes. It had a budget of 19500000.0 USD and grossed 195333312.0 USD in revenue. The movie falls under the genres: drama, fantasy, romance. It was produced by Double Dare You Productions, Fox Searchlight Pictures, Bull Productions, TSG Entertainment. The cast includes Sally Hawkins, Michael Shannon, Richard Jenkins. The story: An other-worldly story, set against the backdrop of Cold War era America circa 1962, where a mute janitor working at a lab falls in love with an amphibious man being held captive there and devises a plan to help him escape.",
    metadata={
        "title": "The Shape of Water",
        "release_date": "2017-12-01",
        "release_date_streaming": "2018-03-13",
        "original_language": "English"
    }
)

doc3 = Document(
    page_content="The movie 'Interstellar' is a English film directed by Christopher Nolan and written by Jonathan Nolan,Christopher Nolan. It was released on 2014-11-05, with a streaming release on 2015-03-31. The film runs for 165.0 minutes and has a TMDB rating of 8.417 based on 32571.0 votes. It had a budget of 165000000.0 USD and grossed 701729206.0 USD in revenue. The movie falls under the genres: adventure, drama, science fiction. It was produced by Legendary Pictures, Syncopy, Lynda Obst Productions. The cast includes Matthew McConaughey, Anne Hathaway, Michael Caine. The story: The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage. ",
    metadata={
        "title": "Interstellar",
        "release_date": "2014-11-05",
        "release_date_streaming": "2015-03-31",
        "original_language": "English"
    }
)

doc4 = Document(
    page_content="The movie 'Inception' is a English film directed by Christopher Nolan and written by Christopher Nolan. It was released on 2010-07-15, with a streaming release on 2010-12-07. The film runs for 148.0 minutes and has a TMDB rating of 8.364 based on 34495.0 votes. It had a budget of 160000000.0 USD and grossed 825532764.0 USD in revenue. The movie falls under the genres: action, science fiction, adventure. It was produced by Legendary Pictures, Syncopy, Warner Bros. Pictures. The cast includes Leonardo DiCaprio, Joseph Gordon-Levitt, Ken Watanabe. The story: Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: \"inception\", the implantation of another person's idea into a target's subconscious. ",
    metadata={
        "title": "Inception",
        "release_date": "2010-07-15",
        "release_date_streaming": "2010-12-07",
        "original_language": "English"
    }
)

doc5 = Document(
    page_content="The movie 'Incendies' is a French (Canada) film directed by Denis Villeneuve and written by Valérie Beaugrand-Champagne,Denis Villeneuve,Wajdi Mouawad. It was released on 2010-09-04, with a streaming release on 2011-03-15. The film runs for 130.0 minutes and has a TMDB rating of 8.098 based on 2334.0 votes. It had a budget of 6800000.0 USD and grossed 6788659.0 USD in revenue. The movie falls under the genres: drama, war, mystery. It was produced by TS Productions, Phi Group, micro_scope, Entertainment One, Téléfilm Canada, Super Écran, CNC, The Movie Network, Société Radio-Canada, Astral Media, Seville International, Sony Pictures Classics. The cast includes Lubna Azabal, Mélissa Désormeaux-Poulin, Maxim Gaudette. The story: A mother's last wishes send twins Jeanne and Simon on a journey to Middle East in search of their tangled roots. Adapted from Wajdi Mouawad's acclaimed play, Incendies tells the powerful and moving tale of two young adults' voyage to the core of deep-rooted hatred, never-ending wars and enduring love.",
    metadata={
        "title": "Incendies",
        "release_date": "2010-09-04",
        "release_date_streaming": "2011-03-15",
        "original_language": "French (Canada)",
    }
)

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory='chroma_db',
    collection_name='sample'
)

# %%
# add documents
vector_store.add_documents(docs)
# Out:
# ['7e78992f-3780-4d22-8776-4523a9b14fc2',
#  '89d12c6f-a376-45ad-862c-abc95bc53d8a',
#  '7276c4d7-bb92-42c9-b875-fb925896ae4e',
#  'd80a25dd-6e76-46c4-b9af-f1aa39fda1a3',
#  '85756be2-8587-4966-bac1-fab4821215b2']

# %%
# view documents
vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['972d912e-bf87-41d0-ba32-a585dd128a22',
#   'af8931a8-9ae3-4420-a07c-a4bc410d86c5',
#   '93bff352-d439-42a8-808f-a616b02aa805',
#   'd5642553-bf3c-4a9a-867b-0bcc64b9172b',
#   'f0b28f0e-6507-4bb4-b528-e43f8e38326a',
#   '19217a7a-e7ce-49dd-a430-d0d54c589fdb',
#   'f4266fd1-4a57-4158-9470-190c565e4edc',
#   '607fc890-6934-4ac0-a892-8306f081d718',
#   '0e181fe2-d9c2-4152-8e81-0d1b519ba3a1',
#   '7e78992f-3780-4d22-8776-4523a9b14fc2',
#   '89d12c6f-a376-45ad-862c-abc95bc53d8a',
#   '7276c4d7-bb92-42c9-b875-fb925896ae4e',
#   'd80a25dd-6e76-46c4-b9af-f1aa39fda1a3',
#   '85756be2-8587-4966-bac1-fab4821215b2'],
#  'embeddings': array([[ 0.00191171, -0.02979797,  0.02314533, ..., -0.06011863,
#           0.04217808,  0.01253708],
#         [-0.04236158, -0.08041894,  0.00526647, ..., -0.03559139,
#           0.00605188,  0.00307221],
#         [-0.08904573,  0.00402627, -0.02028335, ..., -0.03258573,
#           0.04211309, -0.00490045],
#         ...,
# ...

# %%
# search documents
vector_store.similarity_search(
    query="Who are the casts of Inception ?",
    k=2
)
# Out:
# [Document(id='93bff352-d439-42a8-808f-a616b02aa805', metadata={'original_language': 'English', 'title': 'Inception', 'release_date_streaming': '2010-12-07', 'release_date': '2010-07-15'}, page_content='The movie \'Inception\' is a English film directed by Christopher Nolan and written by Christopher Nolan. It was released on 2010-07-15, with a streaming release on 2010-12-07. The film runs for 148.0 minutes and has a TMDB rating of 8.364 based on 34495.0 votes. It had a budget of 160000000.0 USD and grossed 825532764.0 USD in revenue. The movie falls under the genres: action, science fiction, adventure. It was produced by Legendary Pictures, Syncopy, Warner Bros. Pictures. The cast includes Leonardo DiCaprio, Joseph Gordon-Levitt, Ken Watanabe. The story: Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of ano
# ...

# %%
# search documents with similarity score
vector_store.similarity_search_with_score(
    query="Who are the casts of Inception ?",
    k=2
)
# Out:
# [(Document(id='93bff352-d439-42a8-808f-a616b02aa805', metadata={'release_date_streaming': '2010-12-07', 'original_language': 'English', 'release_date': '2010-07-15', 'title': 'Inception'}, page_content='The movie \'Inception\' is a English film directed by Christopher Nolan and written by Christopher Nolan. It was released on 2010-07-15, with a streaming release on 2010-12-07. The film runs for 148.0 minutes and has a TMDB rating of 8.364 based on 34495.0 votes. It had a budget of 160000000.0 USD and grossed 825532764.0 USD in revenue. The movie falls under the genres: action, science fiction, adventure. It was produced by Legendary Pictures, Syncopy, Warner Bros. Pictures. The cast includes Leonardo DiCaprio, Joseph Gordon-Levitt, Ken Watanabe. The story: Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of an
# ...

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="",
    filter={'title': 'Inception'}
)
# Out:
# [(Document(id='93bff352-d439-42a8-808f-a616b02aa805', metadata={'title': 'Inception', 'release_date_streaming': '2010-12-07', 'release_date': '2010-07-15', 'original_language': 'English'}, page_content='The movie \'Inception\' is a English film directed by Christopher Nolan and written by Christopher Nolan. It was released on 2010-07-15, with a streaming release on 2010-12-07. The film runs for 148.0 minutes and has a TMDB rating of 8.364 based on 34495.0 votes. It had a budget of 160000000.0 USD and grossed 825532764.0 USD in revenue. The movie falls under the genres: action, science fiction, adventure. It was produced by Legendary Pictures, Syncopy, Warner Bros. Pictures. The cast includes Leonardo DiCaprio, Joseph Gordon-Levitt, Ken Watanabe. The story: Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of an
# ...

# %%
# update documents
updated_doc1 = Document(
    page_content="The movie 'The Shawshank Redemption' is a English film directed by Frank Darabont and written by Frank Darabont. It was released on 1994-09-23, with a streaming release on 1999-12-21. The film runs for 142.0 minutes and has a TMDB rating of 8.702 based on 24649.0 votes. It had a budget of 25000000.0 USD and grossed 28341469.0 USD in revenue. The movie falls under the genres: drama, crime. It was produced by Castle Rock Entertainment. The cast includes Tim Robbins, Morgan Freeman, Bob Gunton. The story: Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.",
    metadata={
       "title": "The Shawshank Redemption",
        "release_date": "1994-09-23",
        "release_date_streaming": "1999-12-21",
        "original_language": "French",
    }
)

vector_store.update_document(document_id='f14370e5-c12a-4616-a991-72a245b6a3ca', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['972d912e-bf87-41d0-ba32-a585dd128a22',
#   'af8931a8-9ae3-4420-a07c-a4bc410d86c5',
#   '93bff352-d439-42a8-808f-a616b02aa805',
#   'd5642553-bf3c-4a9a-867b-0bcc64b9172b',
#   'f0b28f0e-6507-4bb4-b528-e43f8e38326a',
#   '19217a7a-e7ce-49dd-a430-d0d54c589fdb',
#   'f4266fd1-4a57-4158-9470-190c565e4edc',
#   '607fc890-6934-4ac0-a892-8306f081d718',
#   '0e181fe2-d9c2-4152-8e81-0d1b519ba3a1',
#   '7e78992f-3780-4d22-8776-4523a9b14fc2',
#   '89d12c6f-a376-45ad-862c-abc95bc53d8a',
#   '7276c4d7-bb92-42c9-b875-fb925896ae4e',
#   'd80a25dd-6e76-46c4-b9af-f1aa39fda1a3',
#   '85756be2-8587-4966-bac1-fab4821215b2'],
#  'embeddings': array([[ 0.00191171, -0.02979797,  0.02314533, ..., -0.06011863,
#           0.04217808,  0.01253708],
#         [-0.04236158, -0.08041894,  0.00526647, ..., -0.03559139,
#           0.00605188,  0.00307221],
#         [-0.08904573,  0.00402627, -0.02028335, ..., -0.03258573,
#           0.04211309, -0.00490045],
#         ...,
# ...

# %%
# delete document
vector_store.delete(ids=['f14370e5-c12a-4616-a991-72a245b6a3ca'])

# %%
# view documents
vector_store.get(include=['embeddings', 'documents', 'metadatas'])
# Out:
# {'ids': ['972d912e-bf87-41d0-ba32-a585dd128a22',
#   'af8931a8-9ae3-4420-a07c-a4bc410d86c5',
#   '93bff352-d439-42a8-808f-a616b02aa805',
#   'd5642553-bf3c-4a9a-867b-0bcc64b9172b',
#   'f0b28f0e-6507-4bb4-b528-e43f8e38326a',
#   '19217a7a-e7ce-49dd-a430-d0d54c589fdb',
#   'f4266fd1-4a57-4158-9470-190c565e4edc',
#   '607fc890-6934-4ac0-a892-8306f081d718',
#   '0e181fe2-d9c2-4152-8e81-0d1b519ba3a1',
#   '7e78992f-3780-4d22-8776-4523a9b14fc2',
#   '89d12c6f-a376-45ad-862c-abc95bc53d8a',
#   '7276c4d7-bb92-42c9-b875-fb925896ae4e',
#   'd80a25dd-6e76-46c4-b9af-f1aa39fda1a3',
#   '85756be2-8587-4966-bac1-fab4821215b2'],
#  'embeddings': array([[ 0.00191171, -0.02979797,  0.02314533, ..., -0.06011863,
#           0.04217808,  0.01253708],
#         [-0.04236158, -0.08041894,  0.00526647, ..., -0.03559139,
#           0.00605188,  0.00307221],
#         [-0.08904573,  0.00402627, -0.02028335, ..., -0.03258573,
#           0.04211309, -0.00490045],
#         ...,
# ...
